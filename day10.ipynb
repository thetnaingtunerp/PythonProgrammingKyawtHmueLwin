# %%
import numpy as np
list = [1,2,3,4,5]

sub =np.array([
                [['myan', 20, 'A'],
                ['eng', 30, 'B'],]
                ,
                
                [['maths', 20, 'A'],
                ['his', 50, 'B'],]
               ])
  
sub[1,1, 1:3]
# Out:
# array(['50', 'B'], dtype='<U21')

# %%
mark = np.array([
    [20,10,30],
    [30,20,40],
])

mark.shape
# shap(row, col)
reshape = np.reshape(mark, (3,2))
reshape
# Out:
# array([[20, 10],
#        [30, 30],
#        [20, 40]])
